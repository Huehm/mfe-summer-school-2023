# %% [markdown]
# <a href="https://colab.research.google.com/github/Huehm/mfe-summer-school-2023/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # cách 1: upload file lên local drive

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0fee6f70-38ae-4eae-83b8-a46e5df550dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0fee6f70-38ae-4eae-83b8-a46e5df550dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded["xclara.csv"]))
df
# Out:
#       Unnamed: 0         V1         V2
# 0              1   2.072345  -3.241693
# 1              2  17.936710  15.784810
# 2              3   1.083576   7.319176
# 3              4  11.120670  14.406780
# 4              5  23.711550   2.557729
# ...          ...        ...        ...
# 2995        2996  85.652800  -6.461061
# 2996        2997  82.770880  -2.373299
# 2997        2998  64.465320 -10.501360
# 2998        2999  90.722820 -12.255840
# 2999        3000  64.879760 -24.877310
#
# [3000 rows x 3 columns]

# %% [markdown]
# # cách 2 : từ Github

# %%
url = "https://raw.githubusercontent.com/Huehm/mfe-summer-school-2023/main/xclara.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#       Unnamed: 0         V1         V2
# 0              1   2.072345  -3.241693
# 1              2  17.936710  15.784810
# 2              3   1.083576   7.319176
# 3              4  11.120670  14.406780
# 4              5  23.711550   2.557729
# ...          ...        ...        ...
# 2995        2996  85.652800  -6.461061
# 2996        2997  82.770880  -2.373299
# 2997        2998  64.465320 -10.501360
# 2998        2999  90.722820 -12.255840
# 2999        3000  64.879760 -24.877310
#
# [3000 rows x 3 columns]

# %% [markdown]
# # cách 3: Mouting the drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = "/content/xclara.csv"

df_3 = pd.read_csv(path)
df_3
# Out:
#       Unnamed: 0         V1         V2
# 0              1   2.072345  -3.241693
# 1              2  17.936710  15.784810
# 2              3   1.083576   7.319176
# 3              4  11.120670  14.406780
# 4              5  23.711550   2.557729
# ...          ...        ...        ...
# 2995        2996  85.652800  -6.461061
# 2996        2997  82.770880  -2.373299
# 2997        2998  64.465320 -10.501360
# 2998        2999  90.722820 -12.255840
# 2999        3000  64.879760 -24.877310
#
# [3000 rows x 3 columns]
