# %% [markdown]
# <a href="https://colab.research.google.com/github/Huehm/mfe-summer-school-2023/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {"stt":[1,2,3,4],
        "surname":["nguyễn","phạm", "hà", "trần"],
        "name":["minh", "tuan", "An", "Hoa"]}
df = pd.DataFrame(data)
df
# Out:
#    stt  surname  name
# 0    1  nguyễn  minh
# 1    2    phạm  tuan
# 2    3      hà    An
# 3    4    trần   Hoa

# %%
olds = [20, 24, 25, 30]

# %%
df["olds"] = olds
df
# Out:
#    stt  surname  name  olds
# 0    1  nguyễn  minh    20
# 1    2    phạm  tuan    24
# 2    3      hà    An    25
# 3    4    trần   Hoa    30

# %%
df.insert(3, "Qualification",["Mcs", "Ms", "Mcs", "Mcs"], True)

# %%
df
# Out:
#    stt  surname  name Qualification  olds
# 0    1  nguyễn  minh           Mcs    20
# 1    2    phạm  tuan            Ms    24
# 2    3      hà    An           Mcs    25
# 3    4    trần   Hoa           Mcs    30

# %%
df = df.assign(city = ["HN", "HP", "V", "H"])
df
# Out:
#    stt  surname  name Qualification  olds city
# 0    1  nguyễn  minh           Mcs    20   HN
# 1    2    phạm  tuan            Ms    24   HP
# 2    3      hà    An           Mcs    25    V
# 3    4    trần   Hoa           Mcs    30    H

# %%
jobs = {"teacher":"An", "engineer": "minh", "doctor": "Hoa", "painter" : "tuan"}
address = {'Delhi': 'Jai', 'Bangalore': 'Princi',
           'Patna': 'Gaurav', 'Chennai': 'Anuj'}
df["jobs"]= jobs
df
# Out:
#    stt  surname  name Qualification  olds city jobs
# 0    1  nguyễn  minh           Mcs    20   HN  NaN
# 1    2    phạm  tuan            Ms    24   HP  NaN
# 2    3      hà    An           Mcs    25    V  NaN
# 3    4    trần   Hoa           Mcs    30    H  NaN

# %% [markdown]
# # xóa dòng, cột

# %%
df.drop([1], inplace= True)
df
# Out:
#    stt  surname  name Qualification  olds city jobs
# 0    1  nguyễn  minh           Mcs    20   HN  NaN
# 2    3      hà    An           Mcs    25    V  NaN
# 3    4    trần   Hoa           Mcs    30    H  NaN

# %%
from pandas.core.series import Axis
df.drop("jobs", axis = 1, inplace= True)
df
# Out:
#    stt  surname  name Qualification  olds city
# 0    1  nguyễn  minh           Mcs    20   HN
# 2    3      hà    An           Mcs    25    V
# 3    4    trần   Hoa           Mcs    30    H

# %% [markdown]
# #DataFrame.truncate

# %%
df = pd.DataFrame({'Weight':[45, 88, 56, 15, 71],
                   'Name':['Sam', 'Andrea', 'Alex', 'Robin', 'Kia'],
                   'Age':[14, 25, 55, 8, 21]})
index_ = pd.date_range("2023-07-26 14:00", periods= 5, freq= "H")
df.index = index_
df
# Out:
#                      Weight    Name  Age
# 2023-07-26 14:00:00      45     Sam   14
# 2023-07-26 15:00:00      88  Andrea   25
# 2023-07-26 16:00:00      56    Alex   55
# 2023-07-26 17:00:00      15   Robin    8
# 2023-07-26 18:00:00      71     Kia   21

# %%
result = df.truncate(before="2023-07-26 15:00:00", after="2023-07-26 17:00:00	")
result
# Out:
#                      Weight    Name  Age
# 2023-07-26 15:00:00      88  Andrea   25
# 2023-07-26 16:00:00      56    Alex   55
# 2023-07-26 17:00:00      15   Robin    8

# %%
import numpy as np
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from list
df = pd.DataFrame(dict)

# using isnull() function
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
data = pd.read_csv("/content/employees.csv")
# creating bool series True for NaN values
bool_series = pd.isnull(data["Gender"])

# filtering data
# displaying data only with Gender = NaN
data[bool_series]
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN   4/22/1995         7:18 PM   64714    4.934
# 22      Joshua    NaN    3/8/2012         1:58 AM   90816   18.816
# 27       Scott    NaN   7/11/1991         6:58 PM  122367    5.218
# 31       Joyce    NaN   2/20/2005         2:40 PM   88657   12.752
# 41   Christine    NaN   6/28/2015         1:08 AM   66582   11.308
# ..         ...    ...         ...             ...     ...      ...
# 961    Antonio    NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor    NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen    NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin    NaN   2/10/1991         4:58 PM   38344    3.794
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
#
#     Senior Management                  Team
# 20               True                 Legal
# 22               True       Client Services
# ...

# %%
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# filling missing value using fillna()
df1 = df.fillna(0)
df1
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %%
# Filling null values with the previous ones
df2 = df.fillna(method= "pad")
df2
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
#Filling null value with the next ones
df3 = df.fillna(method="bfill")
df3
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %%
data[10:25]
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy    Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn    Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana  Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna  Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew    Male    9/5/1995         2:12 AM  100612   13.645
# 22     Joshua     NaN    3/8/2012         1:58 AM   90816   18.816
# ...

# %%
data["Gender"].fillna("No gender", inplace = True)
data[10:25]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise     Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie     Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon       Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary       Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly     Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian     Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy       Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn       Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana     Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna     Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois  No gender   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male    9/5/1995         2:12 AM  100612   13.645
# ...

# %%
# will replace  Nan value in dataframe with value -99
data.replace(to_replace = np.nan, value = -99)
data[10:25]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise     Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie     Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon       Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary       Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly     Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian     Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy       Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn       Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana     Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna     Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois  No gender   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male    9/5/1995         2:12 AM  100612   13.645
# ...

# %%
data = pd.read_csv("nba.csv")
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.sort_values("Name",axis = 0, ascending = True,
                 inplace = True, na_position ='last')
data
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
data.sort_values("Salary", axis = 0, ascending = True,
                 inplace = True, na_position ='first')

data
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 273   Alex Stepheson    Memphis Grizzlies    35.0       PF  28.0   6-10
# 397     Axel Toupane       Denver Nuggets     6.0       SG  23.0    6-7
# 350    Briante Weber           Miami Heat    12.0       PG  23.0    6-2
# 171    Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6
# 353    Dorell Wright           Miami Heat    11.0       SF  30.0    6-9
# ..               ...                  ...     ...      ...   ...    ...
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0   6-11
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0   6-11
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
#
#      Weight                College      Salary
# 273   270.0                    USC         NaN
# ...

# %%
data.sort_values(["Team", "Name"], axis=0,
                 ascending=[True,False], inplace=True)

#display
data
# Out:
#                  Name                Team  Number Position   Age Height  \
# 322    Walter Tavares       Atlanta Hawks    22.0        C  24.0    7-3
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 321    Tiago Splitter       Atlanta Hawks    11.0        C  31.0   6-11
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF  32.0    6-7
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# ..                ...                 ...     ...      ...   ...    ...
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# 372       Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
# 457               NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# 322   260.0             NaN   1000000.0
# ...

# %% [markdown]
# # Grouping Data

# %%
# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA']}


# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
df1 = df.groupby('Name')
df1

# %%
df1.first()
# Out:
#         Age  Address Qualification
# Name
# Abhi     32  Aligarh            MA
# Anuj     24   Kanpur            MA
# Gaurav   33  Jaunpur        B.Tech
# Jai      27   Nagpur           Msc
# Princi   32  Kannuaj           Phd

# %%
dict = {
    "ID":[1, 2, 3],
    "Movies":["The Godfather", "Fight Club", "Casablanca"],
    "Week_1_Viewers":[30, 30, 40],
    "Week_2_Viewers":[60, 40, 80],
    "Week_3_Viewers":[40, 20, 20] };

# Convert dictionary to dataframe
df = pd.DataFrame(dict);
df
# Out:
#    ID         Movies  Week_1_Viewers  Week_2_Viewers  Week_3_Viewers
# 0   1  The Godfather              30              60              40
# 1   2     Fight Club              30              40              20
# 2   3     Casablanca              40              80              20

# %%
groupby_dict = {"Week_1_Viewers":"Total_Viewers",
           "Week_2_Viewers":"Total_Viewers",
           "Week_3_Viewers":"Total_Viewers",
           "Movies":"Movies" }

df = df.set_index('ID')
df1 = df.groupby(groupby_dict, axis = 1).sum()
df1
# Out:
#            Movies  Total_Viewers
# ID
# 1   The Godfather            130
# 2      Fight Club             90
# 3      Casablanca            140

# %%
df = pd.read_csv("nba.csv")
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# applying groupby() function to
# group the data on team value.
gk = df.groupby('Team')

# Let's print the first entries
# in all the groups formed.
gk.first()
# Out:
#                                          Name  Number Position   Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore    24.0       SF  26.0    6-5
# Boston Celtics                  Avery Bradley     0.0       PG  25.0    6-2
# Brooklyn Nets                Bojan Bogdanovic    44.0       SG  27.0    6-8
# Charlotte Hornets               Nicolas Batum     5.0       SG  27.0    6-8
# Chicago Bulls                Cameron Bairstow    41.0       PF  25.0    6-9
# Cleveland Cavaliers       Matthew Dellavedova     8.0       PG  25.0    6-4
# Dallas Mavericks              Justin Anderson     1.0       SG  22.0    6-6
# Denver Nuggets                 Darrell Arthur     0.0       PF  28.0    6-9
# Detroit Pistons                  Joel Anthony    50.0        C  33.0    6-9
# Golden State Warriors         Leandro Barbosa    19.0       SG  33.0    6-3
# Houston Rockets                  Trevor Ariza     1.0       SF  30.0    6-8
# ...

# %%
gk

# %%
gk.get_group('Boston Celtics')
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %%
# First grouping based on "Team"
# Within each team we are grouping based on "Position"
gkk = df.groupby(['Team', 'Position'])

# Print the first value in each group
gkk.first()
# Out:
#                                          Name  Number   Age Height  Weight  \
# Team               Position
# Atlanta Hawks      C               Al Horford    15.0  30.0   6-10   245.0
#                    PF          Kris Humphries    43.0  31.0    6-9   235.0
#                    PG         Dennis Schroder    17.0  22.0    6-1   172.0
#                    SF           Kent Bazemore    24.0  26.0    6-5   201.0
#                    SG        Tim Hardaway Jr.    10.0  24.0    6-6   205.0
# ...                                       ...     ...   ...    ...     ...
# Washington Wizards C            Marcin Gortat    13.0  32.0   6-11   240.0
#                    PF             Drew Gooden    90.0  34.0   6-10   250.0
#                    PG          Ramon Sessions     7.0  30.0    6-3   190.0
#                    SF            Jared Dudley     1.0  30.0    6-7   225.0
#                    SG           Alan Anderson     6.0  33.0    6-6   220.0
#
# ...

# %%
df1 = pd.read_csv('Student_data.csv')
df2 = pd.read_csv('Course_enrolled.csv')

inner_join = pd.merge(df1,
                      df2,
                      on ='Name',
                      how ='inner')
Left_join = pd.merge(df1,
                     df2,
                     on ='Name',
                     how ='left')
Right_join = pd.merge(df1,
                      df2,
                      on ='Name',
                      how ='right')
Outer_join = pd.merge(df1,
                      df2,
                      on ='Name',
                      how ='outer')

# %% [markdown]
# # Iterate Over Columns of DataFrame

# %%
import pandas as pd
import numpy as np

technologies = [
            ("Spark", 22000,'30days',1000.0),
            ("PySpark",25000,'50days',2300.0),
            ("Hadoop",23000,'55days',1500.0)
            ]
df = pd.DataFrame(technologies,columns = ['Courses','Fee','Duration','Discount'])
print(df)
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  22000   30days    1000.0
# 1  PySpark  25000   50days    2300.0
# 2   Hadoop  23000   55days    1500.0

# %%
for column in df:
    print(df[column])
# Out:
# 0      Spark
# 1    PySpark
# 2     Hadoop
# Name: Courses, dtype: object
# 0    22000
# 1    25000
# 2    23000
# Name: Fee, dtype: int64
# 0    30days
# 1    50days
# 2    55days
# Name: Duration, dtype: object
# 0    1000.0
# 1    2300.0
# 2    1500.0
# Name: Discount, dtype: float64

# %%
for column in df:
    print(df[column].values)
# Out:
# ['Spark' 'PySpark' 'Hadoop']
# [22000 25000 23000]
# ['30days' '50days' '55days']
# [1000. 2300. 1500.]

# %%
# Iterate over columns using DataFrame.iteritems()
for (colname,colval) in df.iteritems():
    print(colname, colval.values)
# Out:
# Courses ['Spark' 'PySpark' 'Hadoop']
# Fee [22000 25000 23000]
# Duration ['30days' '50days' '55days']
# Discount [1000. 2300. 1500.]
# <ipython-input-4-569fcc84b816>:2: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for (colname,colval) in df.iteritems():

# %%
for (colnam, colval) in df.items():
  print(colnam, colval.values)
# Out:
# Courses ['Spark' 'PySpark' 'Hadoop']
# Fee [22000 25000 23000]
# Duration ['30days' '50days' '55days']
# Discount [1000. 2300. 1500.]

# %%
# Use items()
for name, values in df.items():
   print('{name}: {value}'.format(name=name, value=values[1]))
# Out:
# Courses: PySpark
# Fee: 25000
# Duration: 50days
# Discount: 2300.0

# %%
# Use items()
for name, values in df.items():
   print('{name}: {value}'.format(name=name, value=values))
# Out:
# Courses: 0      Spark
# 1    PySpark
# 2     Hadoop
# Name: Courses, dtype: object
# Fee: 0    22000
# 1    25000
# 2    23000
# Name: Fee, dtype: int64
# Duration: 0    30days
# 1    50days
# 2    55days
# Name: Duration, dtype: object
# Discount: 0    1000.0
# 1    2300.0
# 2    1500.0
# Name: Discount, dtype: float64

# %%
# Iterate over columns in pandas DataFrame using enumerate()
for (index, colname) in enumerate(df):
    print(index, df[colname].values)
# Out:
# 0 ['Spark' 'PySpark' 'Hadoop']
# 1 [22000 25000 23000]
# 2 ['30days' '50days' '55days']
# 3 [1000. 2300. 1500.]

# %%
# Using enumerate()
for (index, column) in enumerate(df):
    print (index, df[column])
# Out:
# 0 0      Spark
# 1    PySpark
# 2     Hadoop
# Name: Courses, dtype: object
# 1 0    22000
# 1    25000
# 2    23000
# Name: Fee, dtype: int64
# 2 0    30days
# 1    50days
# 2    55days
# Name: Duration, dtype: object
# 3 0    1000.0
# 1    2300.0
# 2    1500.0
# Name: Discount, dtype: float64

# %%
# Using enumerate() & Numpy.asarray()
for (index, column) in enumerate(df):
    print (index, np.asarray(df[column]))
# Out:
# 0 ['Spark' 'PySpark' 'Hadoop']
# 1 [22000 25000 23000]
# 2 ['30days' '50days' '55days']
# 3 [1000. 2300. 1500.]
